# %% [markdown]
# ##Setting up

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Mounting Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing dataset

# %%
df=pd.read_csv("/content/drive/My Drive/content/crops-data.csv")
df.head()
# Out:
#    Unnamed: 0  Ph  Rainfall  Humidity  Temperature  Potassium  Nitrogen  \
# 0           0   4        30        32           40         24        46
# 1           1   4        30        33           43         21        47
# 2           2   4        30        33           45         19        47
# 3           3   4        30        34           43         19        48
# 4           4   4        30        34           45         24        50
#
#    Phosphorus   Crop
# 0          21  wheat
# 1          22  wheat
# 2          20  wheat
# 3          20  wheat
# 4          19  wheat

# %%
df['Crop'] = df['Crop'].replace(['mustedplant'],'mustardplant')
del df['Unnamed: 0']
df.tail()
# Out:
#      Ph  Rainfall  Humidity  Temperature  Potassium  Nitrogen  Phosphorus  \
# 898   7        77        11           19         40        55          37
# 899   7        77        12           15         41        59          41
# 900   7        78        10           20         39        56          39
# 901   7        78        15           23         41        57          40
# 902   7        80        10           24         41        59          37
#
#              Crop
# 898  mustardplant
# 899  mustardplant
# 900  mustardplant
# 901  mustardplant
# 902  mustardplant

# %%
df.to_csv("/content/drive/My Drive/content/crops-data.csv")

# %% [markdown]
# ##Exploratory data analysis

# %% [markdown]
# Exploratory data analysis is an approach of analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization methodsIt is a good practice to understand the data first and try to gather as many insights from it. EDA is all about making sense of data.

# %% [markdown]
# Checking any null values

# %%
X=df.iloc[:,0:7]
Y=df.iloc[:,-1]

# %%
df.isnull().sum()
# Out:
# Ph             0
# Rainfall       0
# Humidity       0
# Temperature    0
# Potassium      0
# Nitrogen       0
# Phosphorus     0
# Crop           0
# dtype: int64

# %% [markdown]
# Summary of columns ,its count and their datatypes

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ph           903 non-null    int64
#  1   Rainfall     903 non-null    int64
#  2   Humidity     903 non-null    int64
#  3   Temperature  903 non-null    int64
#  4   Potassium    903 non-null    int64
#  5   Nitrogen     903 non-null    int64
#  6   Phosphorus   903 non-null    int64
#  7   Crop         903 non-null    object
# dtypes: int64(7), object(1)
# memory usage: 56.6+ KB
# None

# %% [markdown]
# Summarizing data based on crops count

# %%
df['Crop'].value_counts()
# Out:
# paddy           386
# wheat           262
# mustardplant    124
# maize            81
# sugarcane        50
# Name: Crop, dtype: int64

# %%
dff= df.sample(frac = 1)
dff.head(10)
# Out:
#      Ph  Rainfall  Humidity  Temperature  Potassium  Nitrogen  Phosphorus  \
# 333   4       142        46           21         24        92          22
# 609   5       170        59           22         32       114          30
# 582   4       169        60           25         33       113          28
# 528   4       168        58           25         34       114          33
# 91    5        31        35           41         23        49          19
# 277   3       131        46           20         27        80          27
# 40    4        35        39           41         19        48          19
# 512   4       168        56           22         36        99          29
# 268   3       131        43           20         22        90          28
# 57    4        37        40           40         21        45          18
#
#       Crop
# 333  paddy
# 609  paddy
# 582  paddy
# 528  paddy
# 91   wheat
# 277  paddy
# 40   wheat
# 512  paddy
# 268  paddy
# 57   wheat

# %% [markdown]
# Statistical details of the data

# %%
df.describe()
# Out:
#               Ph    Rainfall    Humidity  Temperature   Potassium    Nitrogen  \
# count  903.00000  903.000000  903.000000   903.000000  903.000000  903.000000
# mean     4.68660   98.427464   42.931340    28.772979   30.186047   76.483942
# std      0.95828   59.380103   13.502063     8.044393   12.160637   29.459385
# min      3.00000   30.000000    9.000000    15.000000   18.000000   45.000000
# 25%      4.00000   41.000000   35.000000    22.000000   23.000000   50.000000
# 50%      4.00000   71.000000   45.000000    25.000000   27.000000   58.000000
# 75%      5.00000  150.000000   52.000000    34.000000   34.000000  102.000000
# max      7.00000  289.000000   80.000000    45.000000   80.000000  150.000000
#
#        Phosphorus
# count  903.000000
# mean    30.087486
# std     12.193019
# min     18.000000
# 25%     23.000000
# 50%     27.000000
# 75%     34.000000
# max     80.000000

# %% [markdown]
# Shape of data

# %%
df.shape
# Out:
# (903, 8)

# %% [markdown]
# Listing all columns

# %%
df.columns
# Out:
# Index(['Ph', 'Rainfall', 'Humidity', 'Temperature', 'Potassium', 'Nitrogen',
#        'Phosphorus', 'Crop'],
#       dtype='object')

# %% [markdown]
# Correlation MATRIX:
#
# A correlation matrix is simply a table which displays the correlation coefficients for different variables. The matrix depicts the correlation between all the possible pairs of values in a table. It is a powerful tool to summarize a large dataset and to identify and visualize patterns in the given data.

# %%
df.corr()
# Out:
# <ipython-input-20-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Ph  Rainfall  Humidity  Temperature  Potassium  Nitrogen  \
# Ph           1.000000 -0.292755 -0.248949     0.086542   0.413237 -0.155595
# Rainfall    -0.292755  1.000000  0.708201    -0.689774   0.465976  0.924474
# Humidity    -0.248949  0.708201  1.000000    -0.287401   0.289897  0.717478
# Temperature  0.086542 -0.689774 -0.287401     1.000000  -0.360693 -0.622005
# Potassium    0.413237  0.465976  0.289897    -0.360693   1.000000  0.685687
# Nitrogen    -0.155595  0.924474  0.717478    -0.622005   0.685687  1.000000
# Phosphorus   0.413573  0.471187  0.286217    -0.377720   0.969108  0.687989
#
#              Phosphorus
# Ph             0.413573
# Rainfall       0.471187
# Humidity       0.286217
# Temperature   -0.377720
# Potassium      0.969108
# Nitrogen       0.687989
# Phosphorus     1.000000

# %%
figsize=(8, 6)
sns.heatmap(df.corr())
# Out:
# <ipython-input-21-fb209ac85d48>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# KDE plot

# %%
plt.figsize=(10, 8)
sns.kdeplot(data=df, x='Temperature',shade=True,hue='Crop')
# Out:
# <ipython-input-22-2e17d8f12919>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='Temperature',shade=True,hue='Crop')
# <Axes: xlabel='Temperature', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='Rainfall',shade=True,hue='Crop')
# Out:
# <ipython-input-23-19f8d7199843>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x='Rainfall',shade=True,hue='Crop')
# <Axes: xlabel='Rainfall', ylabel='Density'>

# %%
plt.figure(figsize=(16, 6))
sns.relplot(data=df, x='Potassium',y='Nitrogen',kind='line',hue='Crop')

# %% [markdown]
# ##Predictive analysis

# %%
X=df[['Ph', 'Rainfall', 'Humidity', 'Temperature', 'Potassium', 'Nitrogen',
       'Phosphorus']]
Y=df['Crop']

# %% [markdown]
# Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=20)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
df.columns
# Out:
# Index(['Ph', 'Rainfall', 'Humidity', 'Temperature', 'Potassium', 'Nitrogen',
#        'Phosphorus', 'Crop'],
#       dtype='object')

# %%
model.predict([[2,54,5,227,5,9,32]])[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 'mustardplant'

# %%
model.score(X_test,y_test)
# Out:
# 0.9779005524861878

# %% [markdown]
# Decision Tree

# %%
from sklearn import tree
dt=tree.DecisionTreeClassifier()
X=df[['Ph', 'Rainfall', 'Humidity', 'Temperature', 'Potassium', 'Nitrogen',
       'Phosphorus']]
Y=df[['Crop']]

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(X_test,y_test)
# Out:
# 0.9613259668508287

# %%
dt.predict([[4,30,37,21,23,49,20]])[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'maize'

# %%
df.columns[0:7]
# Out:
# Index(['Ph', 'Rainfall', 'Humidity', 'Temperature', 'Potassium', 'Nitrogen',
#        'Phosphorus'],
#       dtype='object')

# %%
from sklearn import tree
fig=plt.figure(figsize=(25,20))
tree.plot_tree(dt);

# %%
from sklearn.neighbors import KNeighborsClassifier
X=df[['Ph', 'Rainfall', 'Humidity', 'Temperature', 'Potassium', 'Nitrogen',
       'Phosphorus']]
Y=df[['Crop']]
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X,Y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=6)
